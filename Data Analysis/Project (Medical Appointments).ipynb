# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import MinMaxScaler

# %%
med = pd.read_csv(r'C:\Users\Mai\OneDrive\Desktop\Summer 2022\AI course\2- Data Analysis\Session 7\Medical Appointments.csv')
med
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
med.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %%
med.isnull().sum()
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# No-show           0
# dtype: int64

# %%
med.duplicated().sum()
# Out:
# 0

# %%
sns.boxplot(x=med['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
df=med[med['Age']>100]
df
# Out:
#           PatientId  AppointmentID Gender          ScheduledDay  \
# 58014  9.762948e+14        5651757      F  2016-05-03T09:14:53Z
# 63912  3.196321e+13        5700278      F  2016-05-16T09:17:44Z
# 63915  3.196321e+13        5700279      F  2016-05-16T09:17:44Z
# 68127  3.196321e+13        5562812      F  2016-04-08T14:29:17Z
# 76284  3.196321e+13        5744037      F  2016-05-30T09:44:51Z
# 90372  2.342836e+11        5751563      F  2016-05-31T10:19:49Z
# 97666  7.482346e+14        5717451      F  2016-05-19T07:57:56Z
#
#              AppointmentDay  Age Neighbourhood  Scholarship  Hipertension  \
# 58014  2016-05-03T00:00:00Z  102     CONQUISTA            0             0
# 63912  2016-05-19T00:00:00Z  115    ANDORINHAS            0             0
# 63915  2016-05-19T00:00:00Z  115    ANDORINHAS            0             0
# 68127  2016-05-16T00:00:00Z  115    ANDORINHAS            0             0
# 76284  2016-05-30T00:00:00Z  115    ANDORINHAS            0             0
# ...

# %%
sns.countplot(x='Diabetes', data=med)
# Out:
# <AxesSubplot:xlabel='Diabetes', ylabel='count'>

# %%
sns.countplot(x='Diabetes', data=med, hue='Gender')
# Out:
# <AxesSubplot:xlabel='Diabetes', ylabel='count'>

# %%
sns.countplot(x='Alcoholism', data=med)
# Out:
# <AxesSubplot:xlabel='Alcoholism', ylabel='count'>

# %%
sns.countplot(x='Alcoholism', data=med,hue='Gender')
# Out:
# <AxesSubplot:xlabel='Alcoholism', ylabel='count'>

# %%
sns.countplot(x='Handcap', data=med,hue='Gender')
# Out:
# <AxesSubplot:xlabel='Handcap', ylabel='count'>

# %%
med[med['Handcap']>1]
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 946     7.282582e+13        5582483      M  2016-04-14T09:26:08Z
# 1665    1.242919e+13        5525497      M  2016-03-30T09:16:41Z
# 1666    1.242919e+13        5525498      M  2016-03-30T09:16:41Z
# 2071    1.242919e+13        5640120      M  2016-04-29T10:08:48Z
# 2091    1.491829e+13        5638626      F  2016-04-29T08:13:59Z
# ...              ...            ...    ...                   ...
# 108376  2.387212e+14        5756931      F  2016-06-01T08:48:28Z
# 109484  3.589495e+14        5752442      M  2016-05-31T11:45:57Z
# 109733  5.662976e+14        5772744      F  2016-06-03T16:11:00Z
# 109975  4.522185e+13        5766970      M  2016-06-02T16:07:36Z
# 110107  7.143714e+14        5761625      F  2016-06-02T06:44:00Z
#
#               AppointmentDay  Age Neighbourhood  Scholarship  Hipertension  \
# 946     2016-04-29T00:00:00Z   94    BELA VISTA            0             1
# ...

# %%
sns.countplot(x='Hipertension', data=med)
# Out:
# <AxesSubplot:xlabel='Hipertension', ylabel='count'>

# %%
sns.countplot(x='Hipertension', data=med, hue='Gender')
# Out:
# <AxesSubplot:xlabel='Hipertension', ylabel='count'>

# %%
sns.countplot(x='Gender',data=med)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
med['Gender'].value_counts()
# Out:
# F    71840
# M    38687
# Name: Gender, dtype: int64

# %%
med['Neighbourhood'].value_counts()
# Out:
# JARDIM CAMBURI                 7717
# MARIA ORTIZ                    5805
# RESISTÊNCIA                    4431
# JARDIM DA PENHA                3877
# ITARARÉ                        3514
#                                ...
# ILHA DO BOI                      35
# ILHA DO FRADE                    10
# AEROPORTO                         8
# ILHAS OCEÂNICAS DE TRINDADE       2
# PARQUE INDUSTRIAL                 1
# Name: Neighbourhood, Length: 81, dtype: int64

# %%
med
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
sns.countplot(x=med['No-show'])
# Out:
# <AxesSubplot:xlabel='No-show', ylabel='count'>

# %%
No_show= med['No-show'].map({"No" : 0, "Yes" :1})
No_show
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 110522    0
# 110523    0
# 110524    0
# 110525    0
# 110526    0
# Name: No-show, Length: 110527, dtype: int64

# %%
med[med['No-show']== 'Yes']
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 6       7.336882e+14        5630279      F  2016-04-27T15:05:12Z
# 7       3.449833e+12        5630575      F  2016-04-27T15:39:58Z
# 11      7.542951e+12        5620163      M  2016-04-26T08:44:12Z
# 17      1.479497e+13        5633460      F  2016-04-28T09:28:57Z
# 20      6.222575e+14        5626083      F  2016-04-27T07:51:14Z
# ...              ...            ...    ...                   ...
# 110484  5.133650e+14        5772155      F  2016-06-03T14:43:56Z
# 110492  6.456342e+14        5786741      M  2016-06-08T08:50:19Z
# 110496  8.544295e+13        5779046      F  2016-06-06T17:35:38Z
# 110515  6.456342e+14        5778621      M  2016-06-06T15:58:05Z
# 110516  6.923772e+13        5780205      F  2016-06-07T07:45:16Z
#
#               AppointmentDay  Age   Neighbourhood  Scholarship  Hipertension  \
# 6       2016-04-29T00:00:00Z   23      GOIABEIRAS            0             0
# ...

# %%
sns.barplot(x='Diabetes',y='Age',data=med)
# Out:
# <AxesSubplot:xlabel='Diabetes', ylabel='Age'>

# %%
sns.boxplot(x='Diabetes',y='Age',data=med)
# Out:
# <AxesSubplot:xlabel='Diabetes', ylabel='Age'>

# %%
med.apply(lambda x : pd.factorize(x)[0]).corr(method='pearson', min_periods=1)
# Out:
#                 PatientId  AppointmentID    Gender  ScheduledDay  \
# PatientId        1.000000       0.645075 -0.002684      0.627431
# AppointmentID    0.645075       1.000000 -0.017935      0.971014
# Gender          -0.002684      -0.017935  1.000000     -0.017019
# ScheduledDay     0.627431       0.971014 -0.017019      1.000000
# AppointmentDay   0.322718       0.612725 -0.003365      0.598149
# Age              0.006347      -0.001095  0.022662     -0.000432
# Neighbourhood   -0.112123      -0.087012  0.012139     -0.085763
# Scholarship     -0.014928       0.000771 -0.114293     -0.000732
# Hipertension     0.007836      -0.004828  0.055718     -0.004782
# Diabetes         0.002232       0.013588 -0.032554      0.013509
# Alcoholism      -0.058273      -0.025579  0.106167     -0.025442
# Handcap         -0.012983       0.000184  0.022814      0.000394
# SMS_received     0.017336       0.069934 -0.046298      0.061779
# ...

# %%
from sklearn.model_selection import train_test_split
x=med[['Hipertension','Age']]
y=med['Diabetes']

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2, random_state=4)

# %%
x_train
# Out:
#         Hipertension  Age
# 59201              0   56
# 109358             0    0
# 58062              0   20
# 58385              0   60
# 38695              0   43
# ...              ...  ...
# 23346              0   20
# 11863              0   40
# 92599              0   23
# 73902              0   22
# 83066              0   29
#
# [88421 rows x 2 columns]

# %%
x_test
# Out:
#         Hipertension  Age
# 100683             1   57
# 90484              0   36
# 12524              0   23
# 46506              0   82
# 58282              1   80
# ...              ...  ...
# 16407              0   15
# 36726              0   43
# 71183              1   69
# 53919              0   21
# 75148              0    1
#
# [22106 rows x 2 columns]

# %%
y_train
# Out:
# 59201     0
# 109358    0
# 58062     0
# 58385     0
# 38695     1
#          ..
# 23346     0
# 11863     0
# 92599     0
# 73902     0
# 83066     0
# Name: Diabetes, Length: 88421, dtype: int64

# %%
y_test
# Out:
# 100683    0
# 90484     0
# 12524     0
# 46506     0
# 58282     0
#          ..
# 16407     0
# 36726     0
# 71183     0
# 53919     0
# 75148     0
# Name: Diabetes, Length: 22106, dtype: int64
